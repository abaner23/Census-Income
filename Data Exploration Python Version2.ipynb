# %% [markdown]
# # Name- Arnab Banerjee(banerjee.146)
# # Course- CSE 5243
# # Lab 1- Data Exploration of Adult Dataset
# ## 01/30/2018

# %% [markdown]
# The adult dataset was first cited in a paper with title “Scaling Up the Accuracy of Naive-Bayes Classifiers: a Decision-Tree Hybrid”.  This dataset was first used to show that the NBTree classifier, which is a hybrid of C4.5 and Naïve-Bayes classifier, introduced in the above paper has a better accuracy rate than both C4.5 and Naïve-Bayes when used individually.
# This data was collected from the census bureau database of 1994. This dataset aims to predict whether a person’s income exceeds $50K/yr based on several attributes. We know that the income of a person will depend on several factors like education, type of job, location of job and others as well. This dataset gives information about incomes of people and the values of the attributes. The dataset will help to establish a relationship between yearly income and the useful attributes which could explain/predict the incomes of people for future purposes.
#
# The dataset contains 14 attributes or independent variables and one dependent variable. Thus, this refers to a supervised learning problem. The attributes are described later.
#
# So each record contains the values of a person’s 14 attributes and the dependent variable value of whether he/she earns less or more than 50k/yr.  There are 32561 training data records in the dataset and 16281 test data records without removing the missing values.
#
# To test our model, we can first find whether our model fits the data well. Depending upon the model used we can use a goodness-of-fit statistic to check the model fitting. For example, deviance can be used to check the model fit in case of logistic regression and R-squared statistic in case the model is linear regression. Once we are sure that our model fits the training data very well, we can evaluate the accuracy of our model by using test dataset and comparing its output with the actual output. If the accuracy is high then we are confident that we have been able to mine useful information from the data.
#
# We can also get other types of information from the data. We can calculate proportions of people earning beyond 50k/year in each country and show a histogram for it. We might also be able to find useful patters within the attributes themselves for example between hours-per-week and country. This will give important information about the average working hours in each country.

# %% [markdown]
# Each attribute are as follows:
#
# 1.	Age- Refers to age of a person. It’s a continuous numeric variable.
# 2.	Workclass- Refers to the type or status of employment the person is associated with. It is a categorical variable with 8 possible values: { Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked}
#
# 3.	Fnlwgt: It’s a demographic score assigned to each individual based on socio-economic characteristics of the population that it represents. It’s a continous variable.
#
#
# 4.	education- Refers to the highest level of education done by the person. It’s a categorical variable with 16 possible values: { Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool }
# 5.	education-num- It’s a categorical variable which contains numeric representation of the education variable. The following mapping exists:
#
# a)	Bachelors- 13
# b)	Some-college-10
# c)	11th- 7
# d)	HS-grad- 9
# e)	Prof-school- 15
# f)	Assoc-acdm-12
# g)	Assoc-voc-11
# h)	9th-5
# i)	7th-8th-4
# j)	12th- 8
# k)	Masters- 14
# l)	1st-4th-2
# m)	10th-6
# n)	Doctorate-16
# o)	5th-6th-3
# p)	Preschool- 1
#
# 6.	marital-status- Refers to the marital status of the person. It’s a categorical variable with 7 possible values :{ Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse. }
# 7.	Occupation- Refers to the occupation of that person. It’s a categorical variable with 14 possible values: {Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces}.
#
#
# 8.	Relationship- It represents what this individual is relative to others. It’s a categorical variable with the following possible values: { Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried}
# 9.	race: Refers to the race of the individual. It’s a categorical variable with 5 possible values:{White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black}.
# 10.	sex: Refers to the gender of the individual. It’s a categorical variable with 2 possible values:{Female, Male}.
# 11.	capital-gain: Refers to a continuous variable which denotes the capital gain(amount of profit earned through sale of property or investment).
# 12.	capital-loss: Refers to a continuous variable which denotes the capital loss(loss incurred due to selling price being less than cost price).
# 13.	hours-per-week: Refers to a continuous variable which denotes the number of hours devoted to work per week.
# 14.	native-country- Refers to the country of origin of the individual. It’s a categorical variable with the following possible values: { United¬States, Cambodia, England, Puerto¬Rico, Canada, Germany, Outlying¬US(Guam¬USVI¬etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican¬Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El¬Salvador, Trinadad&Tobago, Peru, Hong, Holand¬Netherlands }
# 15.	Label: Refers to the dependent variable which contains the information of whether the individual earns more than 50k/year. It’s a categorical and binary variable.

# %% [markdown]
# Number of records with label=’>50k’= 7841(24% of the training dataset)
# Number of records with label=’<=50k’= 24720(76% of the training dataset)
# Since the number of records for label=’>50k’ are significantly large in number and the class probabilities reflect the overall income population distribution we can go ahead with this dataset for training the model.
# There are 24 duplicate rows which can be kept in the training data set since looking at the data set two different people can have the exact same values of the attributes. Most probably it is not an error.
# There are 4262 missing values out of which 1836 are from WorkClass, 1843 from occupation and 583 from native country.  Since there is no way to judge the country of origin and over 90% of the total dataset belong to the United States, there is an error probability of only 10% if we label all the missing native country column values as United States. We therefore enter United States for the 583 missing values.  In the same way, Private is the mostly occurring (69.7%) WorkClass value and thus we can impute the missing values with Private value. In case of occupation there is no clear majority value. Since intuitively the occupation plays a key role in deciding the income we cannot remove the attribute. Since we have over 32000 values, we can sacrifice the 1843 data rows. So, we remove the rows with missing values.

# %% [markdown]
# Important attributes& Statistics:
# From experience the following plays an important role in deciding the income of a person:
# 1. Age
#  count    30718.000000
# mean        38.443584
# std         13.118227
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
#
# In the below graph, the age is divided into 18 bins starting with (16.927, 21.056] and subsequently each interval having width of 5. There is significant amount of variance in the proportions of those who earn more than 50k in their respective category. Individuals in the bins [5-9] have more probability of getting a salary >50k. Thus, this is an important predictor.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mp
import numpy as np
import scipy.stats as stat
import seaborn as sbn
df=pd.read_csv('E:\\Datasets\\adult_edited.csv',header=-1)
age=df.iloc[:,0]
agecat=pd.cut(age,bins=18)
df['agecat'] = agecat
dfg = df.groupby(by=14)
ds1=dfg['agecat'].value_counts()[0].sort_index()
x=np.arange(1,19,1)
ds2=dfg['agecat'].value_counts()[1].sort_index()
l1=np.array(ds1)
l2=np.array(ds2)
plt.figure(figsize=[10,10])
plt.bar(x,l1,color='gray')
plt.bar(x,l2,color='red',bottom=l1)
plt.xticks(np.arange(1,19,1))
plt.title('Class Count vs Age Categories')
gpatch=mp.Patch(color='gray',label='<=50k')


rpatch=mp.Patch(color='red',label='>50k')
plt.legend(handles=[gpatch,rpatch],loc='upper left')
plt.show()

# %% [markdown]
# Hours/week- Most of the individuals have 40 hrs/week of work schedule which is a fairly well known rule.
# The percentage distribution of people among those with less than 40 hrs/week  shows that the percentage having >50k
# salary is very less as compared to >=40 hrs/week. Thus hours/week is a good indicator.
# count    30718.000000
# mean        40.949313
# std         11.985382
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# Given a number (of hours) return a string (hours "bucket")
# based on whether it is less than, equal to, or greater than 40.
def tocat(h):
    return('<40' if h<40 else ('40' if h==40 else '>40') )

# Run the function above on every value in the hours-per-week column,
# then store the results in a new column called hrs_bkt
hrsweek=df.iloc[:,12]
df['hrs_bkt'] = hrsweek.apply(tocat)
x=np.sort(df['hrs_bkt'].unique())
dfg = df.groupby(by=14)
ds1=dfg['hrs_bkt'].value_counts()[0].sort_index()
ds2=dfg['hrs_bkt'].value_counts()[1].sort_index()
l1=np.array(ds1)
l2=np.array(ds2)
plt.figure(figsize=[10,10])
plt.bar(x,l1,color='gray')
plt.bar(x,l2,color='red',bottom=l1)
#plt.xticks(np.arange(1,19,1))
plt.title('Class Count vs Work hours per week')

gpatch=mp.Patch(color='gray',label='<=50k')


rpatch=mp.Patch(color='red',label='>50k')
plt.legend(handles=[gpatch,rpatch],loc='upper left')
plt.show()

# %% [markdown]
# Gender- The percentage of males who make >50k is much more than percentage of females which make >50k thus making this attribute an important one.
#
# count     30718
# unique        2
# Frequency of male: 20788.
# There is almost double the sample size of males in comparison  to females in the dataset but since female population is adequately represented, almost 10000 rows, it won’t affect prediction accuracy.

# %%
dfg = df.groupby(by=14)
ds1=dfg[9].value_counts()[0].sort_index()
x=np.sort(df.iloc[:,9].unique())
ds2=dfg[9].value_counts()[1].sort_index()

l1=np.array(ds1)
l2=np.array(ds2)
plt.figure(figsize=[10,10])
plt.bar(x,l1,color='gray')
plt.bar(x,l2,color='red',bottom=l1)
#plt.xticks(np.arange(1,19,1))
plt.title('Class Count vs Gender')

gpatch=mp.Patch(color='gray',label='<=50k')


rpatch=mp.Patch(color='red',label='>50k')
plt.legend(handles=[gpatch,rpatch],loc='upper left')
plt.show()

# %% [markdown]
# Working class- The percentage of people with >50k is almost the same in for all the working classes except for self-employed-income category and to some extent federal-gov. This means this is might be an important attribute. People with self-employed income status or federal-gov status will have higher probability of earning more than 50k.
# Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14

# %%
dfg = df.groupby(by=14)
ds1=dfg[1].value_counts()[0].sort_index()
x=np.sort(df.iloc[:,1].unique())
ds2=dfg[1].value_counts()[1].sort_index()
l1=np.array(ds1)
l2=np.array(ds2)
l2=np.append(l2,[0])
plt.figure(figsize=[10,10])
plt.bar(x,l1,color='gray')
plt.bar(x,l2,color='red',bottom=l1)

plt.title('Class Count vs Working Class')

gpatch=mp.Patch(color='gray',label='<=50k')


rpatch=mp.Patch(color='red',label='>50k')
plt.legend(handles=[gpatch,rpatch],loc='upper left')
plt.show()

# %% [markdown]
# Education- We ignore education attribute as education-num attribute is a one-to-one mapping with Education.

# %% [markdown]
# Education-num- There is a huge amount of variation in the relative proportions and thus is an important indicator of income. The count of each category is given below. The graph shows that more the level of education more is the relative proportion of people with >50k. The mapping has already been given when I described the attribute education-num.
# 1       46
# 2      156
# 3      303
# 4      573
# 5      463
# 6      831
# 7     1056
# 8      393
# 9     9968
# 10    6775
# 11    1321
# 12    1020
# 13    5182
# 14    1675
# 15     558
# 16     398

# %%
import numpy as np
import matplotlib.patches as mp
dfg = df.groupby(by=14)
ds1=dfg[4].value_counts()[0].sort_index()
x=np.sort(df.iloc[:,4].unique())
ds2=dfg[4].value_counts()[1].sort_index()
l1=np.array(ds1)
l2=np.array(ds2)
l2=np.insert(l2,0,[0])
plt.figure(figsize=[10,10])
plt.bar(x,l1,color='gray')
plt.bar(x,l2,color='red',bottom=l1)
plt.xticks(np.arange(1,17,1))
plt.title('Class Count vs Education')

gpatch=mp.Patch(color='gray',label='<=50k')


rpatch=mp.Patch(color='red',label='>50k')
plt.legend(handles=[gpatch,rpatch],loc='upper left')
plt.show()

# %% [markdown]
# Occupation- Again, there is huge number of variation in relative proportions with Prof-speciality and exec-managerial having the highest ratio of people with >50k.
# Adm-clerical         3770
#  Armed-Forces            9
#  Craft-repair         4099
#  Exec-managerial      4066
#  Farming-fishing       994
#  Handlers-cleaners    1370
#  Machine-op-inspct    2002
#  Other-service        3295
#  Priv-house-serv       149
#  Prof-specialty       4140
#  Protective-serv       649
#  Sales                3650
#  Tech-support          928
#  Transport-moving     1597

# %%
dfg = df.groupby(by=14)
ds1=dfg[6].value_counts()[0].sort_index()
x=np.sort(df.iloc[:,6].unique())
ds2=dfg[6].value_counts()[1].sort_index()
l1=np.array(ds1)
l2=np.array(ds2)
#l2=np.insert(l2,0,[0])
plt.figure(figsize=[25,10])
plt.bar(x,l1,color='gray')
plt.bar(x,l2,color='red',bottom=l1)

plt.title('Class Count vs Occupation')

gpatch=mp.Patch(color='gray',label='<=50k')


rpatch=mp.Patch(color='red',label='>50k')
plt.legend(handles=[gpatch,rpatch],loc='upper left')
plt.show()

# %% [markdown]
# Almost all the categories have similar relative proportions of individuals with >50k except marrid-civ-spouse with almost a ratio of 0.5 showing a person with higher income has greater chance of being married than other categories. The never-married category shows very high number of \<50k showing strong relationship between marriage and income. This is a strong indicator.
# Divorced                  4258
#  Married-AF-spouse           21
#  Married-civ-spouse       14339
#  Married-spouse-absent      389
#  Never-married             9912
#  Separated                  959
#  Widowed                    840

# %%
dfg = df.groupby(by=14)
ds1=dfg[5].value_counts()[0].sort_index()
x=np.sort(df.iloc[:,5].unique())
ds2=dfg[5].value_counts()[1].sort_index()
l1=np.array(ds1)
l2=np.array(ds2)
#l2=np.insert(l2,0,[0])
plt.figure(figsize=[15,10])
plt.bar(x,l1,color='gray')
plt.bar(x,l2,color='red',bottom=l1)

plt.title('Class Count vs Marital Status')

gpatch=mp.Patch(color='gray',label='<=50k')


rpatch=mp.Patch(color='red',label='>50k')
plt.legend(handles=[gpatch,rpatch],loc='upper left')
plt.show()

# %% [markdown]
# Country of Origin- Since the dataset is hugely skewed in favour of United States and not much information is present for other countries we ignore this attribute.

# %% [markdown]
# Race: We notice that Asian-Pac-Islander and White race have higher probability of earning more than 50k while others have very low probability. Thus Race is an important attribute.

# %%
dfg = df.groupby(by=14)
ds1=dfg[8].value_counts()[0].sort_index()
x=np.sort(df.iloc[:,8].unique())
ds2=dfg[8].value_counts()[1].sort_index()
l1=np.array(ds1)
l2=np.array(ds2)
#l2=np.insert(l2,0,[0])
plt.figure(figsize=[10,10])
plt.bar(x,l1,color='gray')
plt.bar(x,l2,color='red',bottom=l1)

plt.title('Class Count vs Race')

gpatch=mp.Patch(color='gray',label='<=50k')


rpatch=mp.Patch(color='red',label='>50k')
plt.legend(handles=[gpatch,rpatch],loc='upper left')
plt.show()

# %% [markdown]
# Relationship: On performing the Chi-squared test to compare the significance of marital status and relationship variables, we observe that chi square value is as large as 34629 and thus p value is 0.0. Thus there is a strong association between marital status and relationship. So, we ignore Relationship attribute.

# %%
marital=df.iloc[:,5]
rel=df.iloc[:,7]

ct1=pd.crosstab(marital,rel)
cs1=stat.chi2_contingency(ct1)
print(cs1)
# Out:
# (36429.285023713186, 0.0, 30, array([[  1.76097506e+03,   1.09021323e+03,   1.27249300e+02,
#           6.27236474e+02,   4.53412266e+02,   1.98913666e+02],
#        [  8.68494043e+00,   5.37681490e+00,   6.27579921e-01,
#           3.09346312e+00,   2.23618074e+00,   9.81020900e-01],
#        [  5.93016004e+03,   3.67134042e+03,   4.28517547e+02,
#           2.11224608e+03,   1.52688551e+03,   6.69850413e+02],
#        [  1.60878182e+02,   9.95990950e+01,   1.16251709e+01,
#           5.73027215e+01,   4.14225861e+01,   1.81722443e+01],
#        [  4.09929188e+03,   2.53785663e+03,   2.96217723e+02,
#           1.46011459e+03,   1.05547731e+03,   4.63041865e+02],
#        [  3.96612279e+02,   2.45541214e+02,   2.86594830e+01,
#           1.41268149e+02,   1.02118921e+02,   4.47999544e+01],
#        [  3.47397617e+02,   2.15072596e+02,   2.51031968e+01,
#           1.23738525e+02,   8.94472296e+01,   3.92408360e+01]]))

# %% [markdown]
# We perform **Principal Component Analysis** on the three continuous variables finalwt, Capital gain and Capital loss. We reduce the dimension to 1 by selecting one principal component which explains 99.5% of the variation in those variables.

# %%
import sklearn.decomposition as dec
import seaborn as sns
df=pd.read_csv('E:\\Datasets\\adult_edited.csv',header=-1)
df_rec=df.iloc[:,[2,10,11]]
pca1=dec.PCA(n_components=1)

pca1.fit(df_rec)
print('Total Variance explained by 1 principal components: %.2f%%' % ( sum(pca1.explained_variance_ratio_) * 100))
# Out:
# Total Variance explained by 1 principal components: 99.50%

# %% [markdown]
# We can use the below variable X_fit as the substitute of the finalwgt,capital gain and capital loss. The below plot shows the distribution of class(0-<=50k,1->50k) with respect to X_fit.

# %%
X_fit=pca1.transform(df_rec)
stub_y = [0] * len(X_fit)
dfpc = pd.DataFrame({'x': X_fit.ravel(), 'y': stub_y})
dfpc['class'] = df.iloc[:,14]
plt.figure(1, figsize=(10,10), dpi=100)
plt.clf()
sns.lmplot(data=dfpc, x="x", y="y", fit_reg=False, hue='class')
plt.show()

# %% [markdown]
# The next matrix Correlation among the continuous attributes shows that continuous attributes are not correlated or very weakly correlated.

# %%
corr_matrix=(df.corr())
# Out:
#           0         2         4         10        11        12        14
# 0   1.000000 -0.076540  0.043567  0.080392  0.060409  0.101879  0.242431
# 2  -0.076540  1.000000 -0.043509 -0.000189 -0.010011 -0.022810 -0.009446
# 4   0.043567 -0.043509  1.000000  0.124247  0.079321  0.151241  0.334640
# 10  0.080392 -0.000189  0.124247  1.000000 -0.032332  0.079548  0.221871
# 11  0.060409 -0.010011  0.079321 -0.032332  1.000000  0.053961  0.151461
# 12  0.101879 -0.022810  0.151241  0.079548  0.053961  1.000000  0.228547
# 14  0.242431 -0.009446  0.334640  0.221871  0.151461  0.228547  1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('E:\\Datasets\\adult_edited.csv',header=-1)
pd.plotting.scatter_matrix(df, figsize=(10, 10))
plt.show()

# %% [markdown]
# The above scatter plot matrix shows that as age(0) increases the finalwgt(2) decreases but the decreases seems to be non-linear and that is why the correlation,(-0.076540), which measures linear relationship, is not significant. From the plot of Working Hours(12) and education-level(4), we can see that there is a positive relationship. We can conclude that lesser educated people have lesser probability to work for more hours than more educated people.

# %% [markdown]
# Even though we find very few relationship among the continuous variables, the p-value of 0.0 obtained from chi-square test between relationship and marital status shows that they are strongly dependent.

# %% [markdown]
# The key relationships between the class atrribute and the other attributes obtained from above graphs are summarized below:
# 1. The probability of >=50k income increases if the working hours per week is >=40.
# 2. More is the level of education the probability of >=50k income increases
# 3. If the individual belongs to Never-Married status his/her probability of >=50k income decreases.
# 4. If the individual belongs to Marrid-civ-Spouse status his/her probability of >=50k income increases.
# 5. Prof-speciality and Exec-Managerial occupation has a higher probability of >=50k income.
# 6. Federal-Govt and Self-employed-inc working class individual has a higher probability of >50k income.
# 7. Persons in the age range within [30,60] has relatively higher probability of >50k income.
# 8. White race& Asian-pac-Islander people have greater chances of >50k income.

# %% [markdown]
# The two new attributes that was created during the data exploration are:
#
# 1. WorkingHours_Categorical- The Working hours attribute was a continuous variable. After looking at the distribution of count of each class for all the values, it was clear that most people belonged to 40 hrs category. Also it was clear that proportion of people with lesser working hours and >50k income was low while opposite was true for more working hours. So I decided to change this attribute to a categorical variable with 3 categories: <40,40,>40.
# 2. Age_Categorical- The Age attribute was a continuous attribute but since income does not change significantly in 1-2 years the age atttribute was divided into bins. Since the age values ranged from 16 to 90, 18 bins was chosen with a width of 5 years.
#
# Following additional attributes could have been added to have better predictive power:
#
# 1. Annual Spending- This could have given a good estimate of the income as logically there should a strong linear relationship between income and spending.
# 2. Number of Credit Cards and other types of cards- This also must be a good indicator of the income of the individual.
